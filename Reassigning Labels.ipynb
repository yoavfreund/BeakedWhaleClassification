# %% [markdown]
# ## Raw Data

# %%
## Histogram of ICI for Clicks labeled as Gervais

# %%
## Histogram for ICI for Clicks labeled aa Cuvier

# %% [markdown]
# # Reassigning Labels
#
# The labels were reassigned on basis of the majority clicks in a given bout.

# %%
## Top Plot: Histogram of Mode ICI for Bout classified as Cuvier

## Bottom Plot: Histogram of Mode ICI for Bout classified as Gervais

# %%
## Histogram of ICI for Clicks classified as Gervais

# %%
## Histogram of ICI for Clicks classified as Cuvier
