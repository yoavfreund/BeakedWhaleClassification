# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /mnt/anaconda/lib/python3.6/site-packages

# %% [markdown]
# ## Importing require dependencies and starting a spark context.

# %%
from pyspark import SparkContext
sc = SparkContext(pyFiles=['lib/numpy_pack.py','lib/row_parser.py','lib/spark_PCA.py'])

from pyspark.sql import Row, SQLContext,DataFrame
from pyspark.sql.types import *

sqlContext = SQLContext(sc)

# %pylab inline

#!pip install pandas
#!pip install scipy

import pandas as pd
import datetime as dt

from scipy.io import loadmat,savemat,whosmat

from string import split
from collections import Counter
import re
import numpy as np
from numpy import shape

from glob import glob
from time import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Loading the Dataset and Parsing the Rows

# %%
import sys
sys.path.append('lib')
from row_parser import *

Parse_rules,field_names,RowObject = init_parser_parameters()

from pyspark.sql import DataFrame

CVS_Data=sc.textFile("/CVS/*/")


def parse(row):
    items=row.split(',')
    D=[]
    for pr in Parse_rules:
        start=pr['start']
        end=pr['end']
        parser=pr['parser']
        if end-start==1:
            D.append(parser(items[start]))
        else:
            D.append(parser(items[start:end]))
    return RowObject(*D)


RDD=CVS_Data.map(parse)

df=sqlContext.createDataFrame(RDD)
# Out:
# ('time', 'datetime') {'start': 0, 'parser': <function parse_date at 0x7f3041363410>, 'end': 1, 'name': 'time'}
# ('species', 'str') {'start': 1, 'parser': <function parse_string at 0x7f30413635f0>, 'end': 2, 'name': 'species'}
# ('site', 'str') {'start': 2, 'parser': <function parse_string at 0x7f30413635f0>, 'end': 3, 'name': 'site'}
# ('rec_no', 'str') {'start': 3, 'parser': <function parse_string at 0x7f30413635f0>, 'end': 4, 'name': 'rec_no'}
# ('bout_i', 'int') {'start': 4, 'parser': <function parse_int at 0x7f3041363500>, 'end': 5, 'name': 'bout_i'}
# ('peak2peak', 'float') {'start': 5, 'parser': <function parse_float at 0x7f3041363578>, 'end': 6, 'name': 'peak2peak'}
# ('MSN', 'array', 202) {'start': 6, 'parser': <function parse_array at 0x7f3041363488>, 'end': 208, 'name': 'MSN'}
# ('MSP', 'array', 101) {'start': 208, 'parser': <function parse_array at 0x7f3041363488>, 'end': 309, 'name': 'MSP'}
# ('TPWS1', 'bool') {'start': 309, 'parser': <function parse_int at 0x7f3041363500>, 'end': 310, 'name': 'TPWS1'}
# ('MD1', 'bool') {'start': 310, 'parser': <function parse_int at 0x7f3041363500>, 'end': 311, 'name': 'MD1'}
# ('FD1', 'bool') {'start': 311, 'parser': <function parse_int at 0x7f3041363500>, 'end': 312, 'name': 'FD1'}
# ('TPWS2', 'bool') {'start': 312, 'parser': <function parse_int at 0x7f3041363500>, 'end': 313, 'name': 'TPWS2'}
# ('MD2', 'bool') {'start': 313, 'parser': <function parse_int at 0x7f3041363500>, 'end': 314, 'name': 'MD2'}
# ('FD2', 'bool') {'start': 314, 'parser': <function parse_int at 0x7f3041363500>, 'end': 315, 'name': 'FD2'}
# ('TPWS3', 'bool') {'start': 315, 'parser': <function parse_int at 0x7f3041363500>, 'end': 316, 'name': 'TPWS3'}
# ('MD3', 'bool') {'start': 316, 'parser': <function parse_int at 0x7f3041363500>, 'end': 317, 'name': 'MD3'}
# ('FD3', 'bool') {'start': 317, 'parser': <function parse_int at 0x7f3041363500>, 'end': 318, 'name': 'FD3'}

# %%
## Caching the Dataframe
df = df = df.filter(df.TPWS2==1).filter(df.MD2==0).filter(df.FD2==0)
df.cache().count()
# Out:
# 4144531

# %% [markdown]
# ## Functions to Read MSP

# %%
from spark_PCA import *
from row_parser import unpackArray

def trimmed_spectra(row):
    return unpackArray(row.MSP,data_type=numpy.float64)[12:85]

def unpackArray(x,data_type=numpy.int16):
    return np.frombuffer(x,dtype=data_type)

# %% [markdown]
# ## Eigen Vector Extraction

# %%
## Get Spectra
spectra=df.rdd.map(trimmed_spectra)

## Extract Eigen Vectors
COV=computeCov(spectra)
eigval,eigvec=LA.eig(COV['Cov'])
eigval=eigval/sum(eigval)

## Check the Reconstruction
plot(cumsum(eigval[:10]))
# Out:
# shape of E= (73,) shape of NE= (73,)

# %%
## Using First 5 Eigen Vectors
V=eigvec[:,0:5]

## Defining a function to return Projection
def project(array):
    return np.dot(array, V)

# %% [markdown]
# ## Interclick Interval

# %% [markdown]
# Writing a UDF to get timestamp with higher precision to calculate Interclick Interval

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import udf, lag, collect_list, col
from pyspark.sql.types import DoubleType

def unix_ts(x):
    from datetime import datetime
    y = datetime.utcfromtimestamp(0)
    return (x-y).total_seconds()

unix_ts_udf = udf(unix_ts, DoubleType())

# %% [markdown]
# Calculating ICI for a given window of bout by sorting them by unix_ts

# %%
df_with_unix_ts = df.withColumn("unix_ts", unix_ts_udf(df.time))
df_with_ici = df_with_unix_ts.withColumn("ici",
                                         df_with_unix_ts.unix_ts - lag(df_with_unix_ts.unix_ts, 1).over(
                                             Window.partitionBy("bout_i").orderBy("unix_ts")
                                         ))

# %% [markdown]
# Calculating ICI per bout by taking median of all the ICI's in the given bout.

# %%
def median(values_list):
    med = np.median(values_list)
    return float(med)

udf_median = udf(median, FloatType())

lookup_grouped = df_with_ici.groupby(['bout_i'])
lookup = lookup_grouped.agg(udf_median(collect_list('ici')).alias('median_ici'))
lookup.cache()
# Out:
# DataFrame[bout_i: bigint, median_ici: float]

# %%
df_final = df_with_ici.alias('a').join(lookup.alias('b'), col('b.bout_i') == col('a.bout_i'))
df_final.cache().count()
# Out:
# 4144531

# %% [markdown]
# ## Defining Features

# %%
def features(row):
    array = trimmed_spectra(row)
    rmse = np.std(array)
    projections = project(array)
    ici = row.median_ici
    #return projections
    
    return np.hstack((projections, [rmse,ici]))

# %% [markdown]
# ## Creating Training and Test Data

# %% [markdown]
# ### Filtering Samples

# %% [markdown]
# Only taking the samples which were neither Misclassified (MS = 0) nor Falsely Detected (FD = 0)

# %%
Cuviers=df_final.filter(df.species==u'Cuviers')
Gervais=df_final.filter(df.species==u'Gervais')

# %% [markdown]
# ### Feature Extraction

# %%
Cuvier_projections=Cuviers.rdd.map(features)
Gervais_projections=Gervais.rdd.map(features)

# %% [markdown]
# ### Adding Labels

# %%
from pyspark.mllib.regression import LabeledPoint
Cuvier_samples = Cuvier_projections.map(lambda features:LabeledPoint(1, features))
Gervais_samples = Gervais_projections.map(lambda features:LabeledPoint(0, features))

# %% [markdown]
# Sample Check

# %%
Cuvier_samples.take(1)
# Out:
# [LabeledPoint(1.0, [-249.591924674,27.3700830202,43.9599370147,-9.10062704605,-8.47665782811,10.2998135252,0.31932091713])]

# %%
Gervais_samples.take(1)
# Out:
# [LabeledPoint(0.0, [-117.435230657,-80.7393481824,91.8636938614,-11.1048393711,-9.50870526181,10.7621986414,0.31932091713])]

# %% [markdown]
# ### Creating Training and Test Data
#
# Splitting the randomly shuffled dataset in 80/20 split for traning and testing

# %%
samples = Cuvier_samples.union(Gervais_samples)
[training_data, test_data] = samples.randomSplit([0.8, 0.2])
training_data.cache()
test_data.cache()
# Out:
# PythonRDD[73] at RDD at PythonRDD.scala:48

# %% [markdown]
# ### Defining Score Metrics
#
# Accuracy is being used as a scoring function

# %%
def score(data, model):
    predictions = model.predict(data.map(lambda x: x.features))
    labels_and_preds = data.map(lambda x: x.label).zip(predictions)
    accuracy = labels_and_preds.filter(lambda x: x[0] == x[1]).count() / float(data.count())
    return accuracy

# %% [markdown]
# ### Logistic Regression Model

# %%
from pyspark.mllib.classification import LogisticRegressionWithSGD

algo = LogisticRegressionWithSGD()
model = algo.train(training_data)
print "Training Accuracy: ", score(training_data, model), ", Test Accuracy: ", score(test_data, model)
# Out:
# /usr/lib/spark/python/pyspark/mllib/classification.py:313: UserWarning: Deprecated in 2.0.0. Use ml.classification.LogisticRegression or LogisticRegressionWithLBFGS.
#   "Deprecated in 2.0.0. Use ml.classification.LogisticRegression or "
# Training Accuracy:  0.744990203601 , Test Accuracy:  0.743868414418

# %% [markdown]
# ## SVM Model

# %%
from pyspark.mllib.classification import SVMWithSGD

algo = SVMWithSGD()
model = algo.train(training_data)
print "Training Accuracy: ", score(training_data, model), ", Test Accuracy: ", score(test_data, model)
# Out:
# Training Accuracy:  0.712891614669 , Test Accuracy:  0.711885137637

# %% [markdown]
# ## Decision Tree

# %%
from pyspark.mllib.tree import DecisionTree

algo = DecisionTree()
model = algo.trainClassifier(training_data,numClasses=2,categoricalFeaturesInfo={})
print "Training Accuracy: ", score(training_data, model), ", Test Accuracy: ", score(test_data, model)
# Out:
# Training Accuracy:  0.853664480574 , Test Accuracy:  0.853442650239

# %% [markdown]
# ## Random Forest

# %%
from pyspark.mllib.tree import RandomForest

algo = RandomForest()
model = algo.trainClassifier(training_data,numClasses=2,categoricalFeaturesInfo={},numTrees=16)
print "Training Accuracy: ", score(training_data, model), ", Test Accuracy: ", score(test_data, model)
# Out:
# Training Accuracy:  0.844501167847 , Test Accuracy:  0.843827764355

# %% [markdown]
# ## GB Trees

# %%
from pyspark.mllib.tree import GradientBoostedTrees

algo = GradientBoostedTrees()
model = algo.trainClassifier(training_data,categoricalFeaturesInfo={}, numIterations=20)
print "Training Accuracy: ", score(training_data, model), ", Test Accuracy: ", score(test_data, model)
# Out:
# Training Accuracy:  0.855676844305 , Test Accuracy:  0.855424491603
